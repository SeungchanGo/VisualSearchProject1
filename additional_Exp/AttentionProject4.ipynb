# %% [markdown]
# # **Bottom-up & Top-down Attention Project**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Input, GlobalAveragePooling2D
from tensorflow.keras.models import Model

# Define IVSN: processes target_image
def build_IVSN(input_shape):
    base_model = VGG16(weights="imagenet", include_top=False, input_tensor=Input(shape=input_shape))

    for layer in base_model.layers:
        layer.trainable = False

    x = base_model.get_layer("block5_conv3").output  # Output: 3x3x512

    # PFC module 추가: average pooling을 통해 1x1x512 output을 만들어냄
    x = GlobalAveragePooling2D(name="PFC_module")(x)  # Final output: 1x1x512

    IVSN = Model(inputs=base_model.input, outputs=x, name="IVSN")
    return IVSN

target_image_shape = (56, 56, 3)
IVSN = build_IVSN(target_image_shape)
print("IVSN Summary:")
IVSN.summary()


# Define search_model: processes search_image
def build_search_model(input_shape):
    base_model = VGG16(weights="imagenet", include_top=False, input_tensor=Input(shape=input_shape))

    for layer in base_model.layers:
        layer.trainable = False

    x = base_model.get_layer("block5_conv3").output  # Output: 7x7x512

    search_model = Model(inputs=base_model.input, outputs=x, name="search_model")
    return search_model


search_image_shape = (224, 224, 3)
search_model = build_search_model(search_image_shape)
print("\nSearch Model Summary:")
search_model.summary()
# Out:
# IVSN Summary:
# Model: "IVSN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 56, 56, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 56, 56, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 56, 56, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 28, 28, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 28, 28, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 28, 28, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 14, 14, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 14, 14, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 14, 14, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 14, 14, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 7, 7, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 7, 7, 512)           │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 7, 7, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 7, 7, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 3, 3, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 3, 3, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 3, 3, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 3, 3, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ PFC_module (GlobalAveragePooling2D)  │ (None, 512)                 │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 14,714,688 (56.13 MB)
# Search Model Summary:
# Model: "search_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
# !pip install visualkeras
import visualkeras
# Visualize IVSN model and save
visualkeras.layered_view(IVSN, to_file='IVSN_architecture.png')
from IPython.display import Image
print("IVSN Model Architecture:")
display(Image('IVSN_architecture.png'))

# Visualize search model and save
visualkeras.layered_view(search_model, to_file='search_model_architecture.png')
print("Search Model Architecture:")
display(Image('search_model_architecture.png'))
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.1.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (11.0.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from visualkeras) (1.26.4)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.19-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (655 bytes)
# Downloading visualkeras-0.1.3-py3-none-any.whl (16 kB)
# Downloading aggdraw-1.3.19-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.7/993.7 kB 13.2 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.19 visualkeras-0.1.3
# IVSN Model Architecture:
# /usr/local/lib/python3.10/dist-packages/visualkeras/layered.py:86: UserWarning: The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.
#   warnings.warn("The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.")
# Search Model Architecture:

# %%
from tensorflow.keras.utils import load_img, img_to_array
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import cv2
from sklearn.metrics.pairwise import cosine_similarity

# target image를 불러와 target size로 전처리
def preprocess_image(image_path, target_size):
    img = load_img(image_path, target_size=target_size)
    img = img_to_array(img)
    img = tf.expand_dims(img, axis=0)
    return img

target_img0 = preprocess_image('/content/drive/MyDrive/Attention/dataset4/target/1.jpg', target_size=(56, 56))
target_img1 = preprocess_image('/content/drive/MyDrive/Attention/dataset4/target/2.jpg', target_size=(56, 56))

# IVSN 모델에서 feature vector 추출
IVSN_output0 = IVSN.predict(target_img0)  # Output: (1, 512)
IVSN_output1 = IVSN.predict(target_img1)  # Output: (1, 512)

# 두 이미지의 feature vector 간 Cosine Similarity 확인
similarity = cosine_similarity(IVSN_output0, IVSN_output1)
print(f"Cosine Similarity between Image 1 and Image 2: {similarity[0][0]:.4f}")

# output 시각화 (1x1x512 output이므로 1차원 그래프로 표시)
output0_flatten = IVSN_output0.flatten()
output1_flatten = IVSN_output1.flatten()

# 각 채널의 활성화 정도 시각화
plt.figure(figsize=(15, 5))
plt.bar(range(len(output0_flatten)), output0_flatten, alpha=0.7, label="Image 1")
plt.bar(range(len(output1_flatten)), output1_flatten, alpha=0.7, label="Image 2")
plt.title("IVSN Output Activation per Channel")
plt.xlabel("Channel Index")
plt.ylabel("Activation Value")
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Cosine Similarity between Image 1 and Image 2: 0.3178

# %%
# Reshape IVSN outputs: IVSN 모델의 2D(1x512) output을 4D(1x1x1x512)로 변환
IVSN_output0_reshaped = tf.expand_dims(tf.expand_dims(IVSN_output0, axis=1), axis=1)
IVSN_output1_reshaped = tf.expand_dims(tf.expand_dims(IVSN_output1, axis=1), axis=1)

# search image를 불러와 target size (224x224)로 전처리
search_img0 = preprocess_image('/content/drive/MyDrive/Attention/dataset4/array/circular_array_1.png', target_size=(224, 224))
search_img1 = preprocess_image('/content/drive/MyDrive/Attention/dataset4/array/circular_array_2.png', target_size=(224, 224))

# Search 모델에서 feature map 추출
attention_map0 = search_model.predict(search_img0)  # Output: (1, 7, 7, 512)
attention_map1 = search_model.predict(search_img1)  # Output: (1, 7, 7, 512)

#attention_map0 = tf.multiply(search_feature_map0, IVSN_output0_reshaped)
#attention_map1 = tf.multiply(search_feature_map1, IVSN_output1_reshaped)


## attention map 시각화
# 1. 1x7x7x512 형태인 attention map을 512개의 channel을 평균내어 1x7x7x1 형태의 attention map 생성
attention_map0_reduced = tf.reduce_mean(attention_map0, axis=-1, keepdims=True)  # Output: (1, 7, 7, 1)
attention_map1_reduced = tf.reduce_mean(attention_map1, axis=-1, keepdims=True)  # Output: (1, 7, 7, 1)

# 2. 시각화를 위해 2D로 변환
attention_map0_2d = tf.squeeze(attention_map0_reduced, axis=[0, -1])  # Output: (7, 7)
attention_map1_2d = tf.squeeze(attention_map1_reduced, axis=[0, -1])  # Output: (7, 7)

# 3. 활성화 값을 시각화를 위해 0~1의 값으로 normalization
attention_map0_normalized = (attention_map0_2d - tf.reduce_min(attention_map0_2d)) / (tf.reduce_max(attention_map0_2d) - tf.reduce_min(attention_map0_2d))
attention_map1_normalized = (attention_map1_2d - tf.reduce_min(attention_map1_2d)) / (tf.reduce_max(attention_map1_2d) - tf.reduce_min(attention_map1_2d))

# 4. matrix를 numpy로 변환
attention_map0_normalized_np = attention_map0_normalized.numpy()
attention_map1_normalized_np = attention_map1_normalized.numpy()

# Plot normalized attention map for Target Image 0
plt.figure(figsize=(8, 6))
plt.imshow(attention_map0_normalized_np, cmap='viridis')
plt.colorbar()
plt.title("Normalized Attention Map for Target Image 0")
plt.show()

# Plot normalized attention map for Target Image 1
plt.figure(figsize=(8, 6))
plt.imshow(attention_map1_normalized_np, cmap='viridis')
plt.colorbar()
plt.title("Normalized Attention Map for Target Image 1")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step

# %%
## overlay attention map 시각화

# 1. Attention map을 시각화 및 처리하기 위해 channel dimension 추가
attention_map0_normalized = tf.expand_dims(attention_map0_normalized, axis=-1)  # Shape: (7, 7, 1)
attention_map1_normalized = tf.expand_dims(attention_map1_normalized, axis=-1)  # Shape: (7, 7, 1)

# 2. 224x224 크기의 search image와 attention map 크기를 맞춤
attention_map0_resized = tf.image.resize(attention_map0_normalized, (224, 224)).numpy()
attention_map1_resized = tf.image.resize(attention_map1_normalized, (224, 224)).numpy()


# 3. Viridis color map을 적용하여 heatmap 생성
attention_map0_colored = cv2.applyColorMap((attention_map0_resized * 255).astype(np.uint8), cv2.COLORMAP_VIRIDIS)
attention_map1_colored = cv2.applyColorMap((attention_map1_resized * 255).astype(np.uint8), cv2.COLORMAP_VIRIDIS)

# 4. heatmap을 RGB 형식으로 변환
attention_map0_colored = cv2.cvtColor(attention_map0_colored, cv2.COLOR_BGR2RGB)
attention_map1_colored = cv2.cvtColor(attention_map1_colored, cv2.COLOR_BGR2RGB)

# 5. Search 이미지를 NumPy 배열로 변환하고 [0, 1] 범위로 정규화
search_img0_np = search_img0[0].numpy() / 255.0
search_img1_np = search_img1[0].numpy() / 255.0

# 6. attention map을 [0, 1] 범위로 정규화
attention_map0_colored = attention_map0_colored.astype(np.float32) / 255.0
attention_map1_colored = attention_map1_colored.astype(np.float32) / 255.0

# 7. Heatmap과 원본 이미지를 투명도 0.6으로 중첩
overlay_alpha = 0.6  # Transparency factor
overlay0 = cv2.addWeighted(search_img0_np, 1 - overlay_alpha, attention_map0_colored, overlay_alpha, 0)
overlay1 = cv2.addWeighted(search_img1_np, 1 - overlay_alpha, attention_map1_colored, overlay_alpha, 0)


# target image를 시각화하기 위한 형태로 변환
target_img0_np = target_img0[0].numpy() / 255.0  # Normalize to [0, 1]
target_img1_np = target_img1[0].numpy() / 255.0

# Plot Target Images, Overlays, and Search Images
plt.figure(figsize=(15, 10))

# Target Image 0
plt.subplot(3, 2, 1)
plt.imshow(target_img0_np)
plt.title("Target Image 0")
plt.axis('off')

# Target Image 1
plt.subplot(3, 2, 2)
plt.imshow(target_img1_np)
plt.title("Target Image 1")
plt.axis('off')

# Overlay 0
plt.subplot(3, 2, 3)
plt.imshow(overlay0)
plt.title("Overlay for Target Image 0")
plt.axis('off')

# Overlay 1
plt.subplot(3, 2, 4)
plt.imshow(overlay1)
plt.title("Overlay for Target Image 1")
plt.axis('off')

# Search Image 0
plt.subplot(3, 2, 5)
plt.imshow(search_img0_np)
plt.title("Search Image 0")
plt.axis('off')

# Search Image 1
plt.subplot(3, 2, 6)
plt.imshow(search_img1_np)
plt.title("Search Image 1")
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
import os
from tensorflow.keras.utils import load_img, img_to_array
import tensorflow as tf
import numpy as np
import cv2

# 경로 설정
target_dir = '/content/drive/MyDrive/Attention/dataset4/target'
search_dir = '/content/drive/MyDrive/Attention/dataset4/array'
output_dir = '/content/drive/MyDrive/Attention/dataset4/heatmap'

# Output 경로 생성
os.makedirs(output_dir, exist_ok=True)

# 이미지 전처리
def preprocess_image(image_path, target_size):
    img = load_img(image_path, target_size=target_size)
    img = img_to_array(img)
    img = tf.expand_dims(img, axis=0)
    return img

# Attention Map 생성
def generate_attention_map(search_img, ivsn_output, search_model):
    search_feature_map = search_model.predict(search_img)  # Output: (1, 7, 7, 512)
    ivsn_output_reshaped = tf.expand_dims(tf.expand_dims(ivsn_output, axis=1), axis=1)  # Shape: (1, 1, 1, 512)
    attention_map = tf.multiply(search_feature_map, ivsn_output_reshaped)
    attention_map_reduced = tf.reduce_mean(attention_map, axis=-1, keepdims=True)  # Output: (1, 7, 7, 1)
    attention_map_2d = tf.squeeze(attention_map_reduced, axis=[0, -1])  # Output: (7, 7)
    attention_map_normalized = (attention_map_2d - tf.reduce_min(attention_map_2d)) / (
        tf.reduce_max(attention_map_2d) - tf.reduce_min(attention_map_2d)
    )
    return attention_map_normalized

# Heatmap Overlay 생성
def overlay_heatmap(search_img, attention_map_normalized, alpha=0.6):
    attention_map_resized = tf.image.resize(tf.expand_dims(attention_map_normalized, axis=-1), (224, 224)).numpy()
    attention_map_colored = cv2.applyColorMap((attention_map_resized * 255).astype(np.uint8), cv2.COLORMAP_VIRIDIS)
    attention_map_colored = cv2.cvtColor(attention_map_colored, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0
    search_img_np = search_img[0].numpy().astype(np.float32) / 255.0
    overlay = cv2.addWeighted(search_img_np, 1 - alpha, attention_map_colored, alpha, 0)
    return overlay

# 모든 이미지를 처리
for i in range(1, 301):
    # 이미지 경로 생성
    target_image_path = os.path.join(target_dir, f"{i}.jpg")
    search_image_path = os.path.join(search_dir, f"circular_array_{i}.png")
    output_image_path = os.path.join(output_dir, f"heatmap_{i}.png")

    # 이미지 존재 여부 확인
    if not os.path.exists(target_image_path):
        print(f"Target image {target_image_path} not found. Skipping.")
        continue
    if not os.path.exists(search_image_path):
        print(f"Search image {search_image_path} not found. Skipping.")
        continue

    try:
        # 이미지 전처리
        target_img = preprocess_image(target_image_path, target_size=(56, 56))
        search_img = preprocess_image(search_image_path, target_size=(224, 224))

        # IVSN 출력 생성
        ivsn_output = IVSN.predict(target_img)

        # Attention Map 생성
        attention_map_normalized = generate_attention_map(search_img, ivsn_output, search_model)

        # Heatmap Overlay 생성
        overlay = overlay_heatmap(search_img, attention_map_normalized)

        # Overlay 저장
        overlay_bgr = (overlay * 255).astype(np.uint8)  # OpenCV는 BGR 포맷으로 저장
        cv2.imwrite(output_image_path, cv2.cvtColor(overlay_bgr, cv2.COLOR_RGB2BGR))

        print(f"Saved heatmap for image {i} at {output_image_path}")
    except Exception as e:
        print(f"Error processing image {i}: {e}")
        continue

print("All heatmaps have been generated and saved.")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Saved heatmap for image 1 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 965ms/step
# Saved heatmap for image 2 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_2.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step
# Saved heatmap for image 3 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_3.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# Saved heatmap for image 4 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_4.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step
# Saved heatmap for image 5 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_5.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# Saved heatmap for image 6 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_6.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step
# Saved heatmap for image 7 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_7.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/8.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# Saved heatmap for image 9 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_9.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 903ms/step
# Saved heatmap for image 10 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_10.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step
# Saved heatmap for image 11 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_11.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step
# Saved heatmap for image 12 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_12.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step
# Saved heatmap for image 13 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_13.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step
# Saved heatmap for image 14 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_14.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 629ms/step
# Saved heatmap for image 15 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_15.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step
# Saved heatmap for image 16 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_16.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step
# Saved heatmap for image 17 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_17.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# Saved heatmap for image 18 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_18.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 909ms/step
# Saved heatmap for image 19 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_19.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 880ms/step
# Saved heatmap for image 20 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_20.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/21.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# Saved heatmap for image 22 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_22.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 849ms/step
# Saved heatmap for image 23 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_23.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/24.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step
# Saved heatmap for image 25 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_25.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# Saved heatmap for image 26 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_26.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/27.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/28.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step
# Saved heatmap for image 29 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_29.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/30.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 568ms/step
# Saved heatmap for image 31 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_31.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 662ms/step
# Saved heatmap for image 32 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_32.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step
# Saved heatmap for image 33 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_33.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step
# Saved heatmap for image 34 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_34.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step
# Saved heatmap for image 35 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_35.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# Saved heatmap for image 36 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_36.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/37.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step
# Saved heatmap for image 38 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_38.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step
# Saved heatmap for image 39 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_39.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 844ms/step
# Saved heatmap for image 40 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_40.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 932ms/step
# Saved heatmap for image 41 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_41.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/42.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 916ms/step
# Saved heatmap for image 43 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_43.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 889ms/step
# Saved heatmap for image 44 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_44.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/45.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/46.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/47.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/48.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# Saved heatmap for image 49 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_49.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# Saved heatmap for image 50 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_50.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/51.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# Saved heatmap for image 52 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_52.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step
# Saved heatmap for image 53 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_53.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/54.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Saved heatmap for image 55 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_55.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 745ms/step
# Saved heatmap for image 56 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_56.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Saved heatmap for image 57 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_57.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 876ms/step
# Saved heatmap for image 58 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_58.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 550ms/step
# Saved heatmap for image 59 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_59.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# Saved heatmap for image 60 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_60.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step
# Saved heatmap for image 61 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_61.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# Saved heatmap for image 62 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_62.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 771ms/step
# Saved heatmap for image 63 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_63.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
# Saved heatmap for image 64 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_64.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step
# Saved heatmap for image 65 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_65.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 881ms/step
# Saved heatmap for image 66 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_66.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Saved heatmap for image 67 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_67.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 687ms/step
# Saved heatmap for image 68 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_68.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step
# Saved heatmap for image 69 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_69.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step
# Saved heatmap for image 70 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_70.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 823ms/step
# Saved heatmap for image 71 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_71.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step
# Saved heatmap for image 72 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_72.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 543ms/step
# Saved heatmap for image 73 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_73.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 899ms/step
# Saved heatmap for image 74 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_74.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 911ms/step
# Saved heatmap for image 75 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_75.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 803ms/step
# Saved heatmap for image 76 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_76.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# Saved heatmap for image 77 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_77.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step
# Saved heatmap for image 78 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_78.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step
# Saved heatmap for image 79 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_79.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/80.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# Saved heatmap for image 81 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_81.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step
# Saved heatmap for image 82 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_82.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/83.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/84.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step
# Saved heatmap for image 85 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_85.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 898ms/step
# Saved heatmap for image 86 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_86.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 951ms/step
# Saved heatmap for image 87 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_87.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/88.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 591ms/step
# Saved heatmap for image 89 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_89.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# Saved heatmap for image 90 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_90.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# Saved heatmap for image 91 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_91.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step
# Saved heatmap for image 92 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_92.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 548ms/step
# Saved heatmap for image 93 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_93.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# Saved heatmap for image 94 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_94.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# Saved heatmap for image 95 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_95.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# Saved heatmap for image 96 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_96.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 925ms/step
# Saved heatmap for image 97 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_97.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/98.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/99.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/100.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 859ms/step
# Saved heatmap for image 101 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_101.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/102.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step
# Saved heatmap for image 103 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_103.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step
# Saved heatmap for image 104 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_104.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# Saved heatmap for image 105 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_105.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/106.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/107.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step
# Saved heatmap for image 108 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_108.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# Saved heatmap for image 109 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_109.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step
# Saved heatmap for image 110 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_110.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# Saved heatmap for image 111 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_111.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/112.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 921ms/step
# Saved heatmap for image 113 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_113.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Saved heatmap for image 114 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_114.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/115.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 707ms/step
# Saved heatmap for image 116 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_116.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 768ms/step
# Saved heatmap for image 117 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_117.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 568ms/step
# Saved heatmap for image 118 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_118.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step
# Saved heatmap for image 119 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_119.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 550ms/step
# Saved heatmap for image 120 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_120.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 916ms/step
# Saved heatmap for image 121 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_121.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 902ms/step
# Saved heatmap for image 122 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_122.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step
# Saved heatmap for image 123 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_123.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step
# Saved heatmap for image 124 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_124.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step
# Saved heatmap for image 125 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_125.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step
# Saved heatmap for image 126 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_126.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# Saved heatmap for image 127 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_127.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# Saved heatmap for image 128 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_128.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step
# Saved heatmap for image 129 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_129.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 726ms/step
# Saved heatmap for image 130 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_130.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/131.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step
# Saved heatmap for image 132 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_132.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Saved heatmap for image 133 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_133.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step
# Saved heatmap for image 134 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_134.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# Saved heatmap for image 135 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_135.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/136.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# Saved heatmap for image 137 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_137.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step
# Saved heatmap for image 138 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_138.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step
# Saved heatmap for image 139 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_139.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step
# Saved heatmap for image 140 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_140.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/141.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/142.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/143.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step
# Saved heatmap for image 144 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_144.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 848ms/step
# Saved heatmap for image 145 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_145.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 860ms/step
# Saved heatmap for image 146 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_146.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step
# Saved heatmap for image 147 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_147.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step
# Saved heatmap for image 148 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_148.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/149.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step
# Saved heatmap for image 150 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_150.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step
# Saved heatmap for image 151 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_151.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# Saved heatmap for image 152 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_152.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# Saved heatmap for image 153 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_153.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step
# Saved heatmap for image 154 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_154.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 725ms/step
# Saved heatmap for image 155 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_155.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step
# Saved heatmap for image 156 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_156.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 749ms/step
# Saved heatmap for image 157 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_157.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step
# Saved heatmap for image 158 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_158.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step
# Saved heatmap for image 159 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_159.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step
# Saved heatmap for image 160 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_160.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# Saved heatmap for image 161 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_161.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step
# Saved heatmap for image 162 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_162.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step
# Saved heatmap for image 163 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_163.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/164.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step
# Saved heatmap for image 165 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_165.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/166.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/167.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 954ms/step
# Saved heatmap for image 168 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_168.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 907ms/step
# Saved heatmap for image 169 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_169.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 500ms/step
# Saved heatmap for image 170 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_170.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/171.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step
# Saved heatmap for image 172 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_172.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# Saved heatmap for image 173 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_173.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step
# Saved heatmap for image 174 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_174.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/175.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step
# Saved heatmap for image 176 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_176.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step
# Saved heatmap for image 177 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_177.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step
# Saved heatmap for image 178 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_178.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 892ms/step
# Saved heatmap for image 179 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_179.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/180.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 856ms/step
# Saved heatmap for image 181 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_181.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step
# Saved heatmap for image 182 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_182.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step
# Saved heatmap for image 183 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_183.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step
# Saved heatmap for image 184 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_184.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# Saved heatmap for image 185 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_185.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step
# Saved heatmap for image 186 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_186.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step
# Saved heatmap for image 187 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_187.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step
# Saved heatmap for image 188 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_188.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 589ms/step
# Saved heatmap for image 189 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_189.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 875ms/step
# Saved heatmap for image 190 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_190.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/191.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 917ms/step
# Saved heatmap for image 192 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_192.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step
# Saved heatmap for image 193 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_193.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step
# Saved heatmap for image 194 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_194.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# Saved heatmap for image 195 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_195.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/196.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step
# Saved heatmap for image 197 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_197.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# Saved heatmap for image 198 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_198.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/199.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/200.jpg not found. Skipping.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
# Saved heatmap for image 201 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_201.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step
# Saved heatmap for image 202 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_202.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 712ms/step
# Saved heatmap for image 203 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_203.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 925ms/step
# Saved heatmap for image 204 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_204.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step
# Saved heatmap for image 205 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_205.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# Saved heatmap for image 206 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_206.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# Saved heatmap for image 207 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_207.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# Saved heatmap for image 208 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_208.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 500ms/step
# Saved heatmap for image 209 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_209.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step
# Saved heatmap for image 210 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_210.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step
# Saved heatmap for image 211 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_211.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# Saved heatmap for image 212 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_212.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step
# Saved heatmap for image 213 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_213.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 901ms/step
# Saved heatmap for image 214 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_214.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step
# Saved heatmap for image 215 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_215.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step
# Saved heatmap for image 216 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_216.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
# Saved heatmap for image 217 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_217.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step
# Saved heatmap for image 218 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_218.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step
# Saved heatmap for image 219 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_219.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step
# Saved heatmap for image 220 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_220.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step
# Saved heatmap for image 221 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_221.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step
# Saved heatmap for image 222 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_222.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 786ms/step
# Saved heatmap for image 223 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_223.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 911ms/step
# Saved heatmap for image 224 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_224.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 971ms/step
# Saved heatmap for image 225 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_225.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# Saved heatmap for image 226 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_226.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# Saved heatmap for image 227 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_227.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step
# Saved heatmap for image 228 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_228.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step
# Saved heatmap for image 229 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_229.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step
# Saved heatmap for image 230 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_230.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step
# Saved heatmap for image 231 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_231.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# Saved heatmap for image 232 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_232.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# Saved heatmap for image 233 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_233.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 742ms/step
# Saved heatmap for image 234 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_234.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step
# Saved heatmap for image 235 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_235.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 647ms/step
# Saved heatmap for image 236 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_236.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# Saved heatmap for image 237 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_237.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step
# Saved heatmap for image 238 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_238.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step
# Saved heatmap for image 239 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_239.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step
# Saved heatmap for image 240 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_240.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step
# Saved heatmap for image 241 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_241.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step
# Saved heatmap for image 242 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_242.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# Saved heatmap for image 243 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_243.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 688ms/step
# Saved heatmap for image 244 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_244.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 872ms/step
# Saved heatmap for image 245 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_245.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 910ms/step
# Saved heatmap for image 246 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_246.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 543ms/step
# Saved heatmap for image 247 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_247.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step
# Saved heatmap for image 248 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_248.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# Saved heatmap for image 249 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_249.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step
# Saved heatmap for image 250 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_250.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# Saved heatmap for image 251 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_251.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step
# Saved heatmap for image 252 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_252.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# Saved heatmap for image 253 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_253.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 936ms/step
# Saved heatmap for image 254 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_254.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 877ms/step
# Saved heatmap for image 255 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_255.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# Saved heatmap for image 256 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_256.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step
# Saved heatmap for image 257 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_257.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
# Saved heatmap for image 258 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_258.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step
# Saved heatmap for image 259 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_259.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step
# Saved heatmap for image 260 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_260.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step
# Saved heatmap for image 261 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_261.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step
# Saved heatmap for image 262 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_262.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# Saved heatmap for image 263 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_263.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 930ms/step
# Saved heatmap for image 264 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_264.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 887ms/step
# Saved heatmap for image 265 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_265.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step
# Saved heatmap for image 266 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_266.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# Saved heatmap for image 267 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_267.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step
# Saved heatmap for image 268 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_268.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step
# Saved heatmap for image 269 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_269.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step
# Saved heatmap for image 270 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_270.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step
# Saved heatmap for image 271 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_271.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# Saved heatmap for image 272 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_272.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# Saved heatmap for image 273 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_273.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 741ms/step
# Saved heatmap for image 274 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_274.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 979ms/step
# Saved heatmap for image 275 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_275.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step
# Saved heatmap for image 276 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_276.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step
# Saved heatmap for image 277 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_277.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step
# Saved heatmap for image 278 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_278.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step
# Saved heatmap for image 279 at /content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_279.png
# Target image /content/drive/MyDrive/Attention/dataset4/target/280.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/281.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/282.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/283.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/284.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/285.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/286.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/287.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/288.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/289.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/290.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/291.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/292.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/293.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/294.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/295.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/296.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/297.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/298.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/299.jpg not found. Skipping.
# Target image /content/drive/MyDrive/Attention/dataset4/target/300.jpg not found. Skipping.
# All heatmaps have been generated and saved.

# %%
import numpy as np
import matplotlib.pyplot as plt

## overlay attention map

# Parameters
original_canvas_size = 800  # Original canvas size
scaled_canvas_size = 224  # Scaled canvas size
radius_ratio = scaled_canvas_size / original_canvas_size  # Ratio for scaling
radius = 327 * radius_ratio  # Adjusted radius for the scaled image
image_size = (224, 224)  # Size of each image in the original context
num_images = 6  # Number of images

# Calculate the angles for image placement
angles = np.linspace(0, 2 * np.pi, num_images, endpoint=False)

# Calculate center coordinates for each image, scaled to fit in 224x224
image_centers = []
for angle in angles:
    x = int(scaled_canvas_size / 2 + radius * np.cos(angle) - image_size[0] / 2)
    y = int(scaled_canvas_size / 2 + radius * np.sin(angle) - image_size[1] / 2)
    image_centers.append((x + image_size[0] // 2, y + image_size[1] // 2))

# Display the results
print("Center coordinates for each image within a 224x224 canvas:")
for idx, center in enumerate(image_centers, start=1):
    print(f"Image {idx}: Center at {center}")

# Optional: Plotting the points on a canvas to visualize
fig, ax = plt.subplots()
ax.imshow(np.zeros((scaled_canvas_size, scaled_canvas_size, 3), dtype=np.uint8), extent=[0, scaled_canvas_size, 0, scaled_canvas_size])
for center in image_centers:
    circle = plt.Circle(center, 5, color='red', fill=True)
    ax.add_patch(circle)
ax.set_xlim(0, scaled_canvas_size)
ax.set_ylim(0, scaled_canvas_size)
ax.set_aspect('equal')
plt.gca().invert_yaxis()  # Invert y-axis to match image coordinates
plt.show()


import cv2
import numpy as np
import matplotlib.pyplot as plt

# 224x224 이미지 생성 (배경은 검은색)
image = np.zeros((224, 224, 3), dtype=np.uint8)

# 이미지 중심 좌표 및 크기
center_positions = [(203, 112), (157, 191), (67, 191), (21, 112), (67, 33), (157, 33)]
image_size = 44  # 스케일 다운된 이미지 크기

# 각 중심 위치에 테두리를 그리고 이미지 추가 (여기서는 간단한 흰색 사각형으로 대체)
for center in center_positions:
    top_left = (center[0] - image_size // 2, center[1] - image_size // 2)
    bottom_right = (center[0] + image_size // 2, center[1] + image_size // 2)
    cv2.rectangle(image, top_left, bottom_right, (255, 255, 255), -1)  # 흰색 사각형으로 이미지 영역 표시
    cv2.rectangle(image, top_left, bottom_right, (0, 255, 0), 1)  # 테두리 그리기 (녹색)

    # 중심 좌표 표시
    font = cv2.FONT_HERSHEY_SIMPLEX
    text = f"({center[0]}, {center[1]})"
    text_size = cv2.getTextSize(text, font, 0.4, 1)[0]
    text_x = center[0] - text_size[0] // 2
    text_y = center[1] + text_size[1] // 2
    cv2.putText(image, text, (text_x, text_y), font, 0.4, (255, 0, 0), 1)

# 이미지 출력
plt.figure(figsize=(6, 6))
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# Center coordinates for each image within a 224x224 canvas:
# Image 1: Center at (203, 112)
# Image 2: Center at (157, 191)
# Image 3: Center at (67, 191)
# Image 4: Center at (21, 112)
# Image 5: Center at (67, 33)
# Image 6: Center at (157, 33)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2

# 데이터 준비
file_path = '/content/drive/MyDrive/Attention/dataset4/data.xlsx'
data = pd.read_excel(file_path)

# Location 정의 (데이터에서의 tloc 좌표)
locations = {
    0: (33, 157),
    1: (112, 203),
    2: (191, 157),
    3: (191, 67),
    4: (112, 21),
    5: (33, 67)
}

# Target Label 정의
target_labels = {
    0: "cat",
    1: "cattle",
    2: "horse",
    3: "kite",
    4: "sheep",
    5: "teddybear"
}


def define_ROI(fixed_locations, region_size=22):
    """
    Reigion Of Interest 정의 (44x44 matrix 생성).
    """
    return [
        (
            max(0, y - region_size), min(224, y + region_size),
            max(0, x - region_size), min(224, x + region_size)
        )
        for y, x in fixed_locations
    ]


def WTA_with_IOR(attention_map, search_regions, target_region_index, max_fixations=6):
    """
    Attention Map을 기반으로 목표를 탐색.
    """
    attention_map = attention_map.copy()
    fixation_points = [(112, 112)]  # 초기 고정점: Attention Map 중심
    excluded_regions = set()  # 탐색에서 제외된 영역

    for _ in range(max_fixations):
        max_value, max_location, max_region_index = -np.inf, None, None

        # 현재 탐색 가능한 영역 중 최대값 찾기
        for i, region in enumerate(search_regions):
            if i in excluded_regions:
                continue
            y_min, y_max, x_min, x_max = region
            region_values = attention_map[y_min:y_max, x_min:x_max]
            local_max_idx = np.unravel_index(np.argmax(region_values), region_values.shape)
            global_max_idx = (y_min + local_max_idx[0], x_min + local_max_idx[1])

            if attention_map[global_max_idx] > max_value:
                max_value, max_location, max_region_index = attention_map[global_max_idx], global_max_idx, i

        # 목표 영역인지 확인
        if max_region_index == target_region_index:
            fixation_points.append(max_location)
            return fixation_points, True

        # 목표 영역이 아니면 해당 영역 제외(Inhibition Of Region 적용)
        excluded_regions.add(max_region_index)
        fixation_points.append(max_location)

    return fixation_points, False


def visualize_search(attention_map, fixation_points):
    """
    탐색 경로를 시각화. 중심 fixation은 '+'로 표시. 범례는 이미지 외부로 이동.
    """
    plt.figure(figsize=(6, 6))
    plt.imshow(attention_map, cmap="viridis")

    for i, (y, x) in enumerate(fixation_points):
        if i == 0:
            plt.plot(x, y, marker='+', markersize=12, color="red", label="Center Fixation")
        else:
            plt.scatter(x, y, c="red", label="Fixation" if i == 1 else None)
            plt.text(x, y, str(i), color="white", fontsize=8)

    plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=2, frameon=False)
    plt.title("Search Process")
    plt.show()


# Fixed Locations 및 IOR 정의
fixed_locations = list(locations.values())
search_regions = define_ROI(fixed_locations, region_size=22)

# %%
image_idx = 201

# Attention Map 로드 (예제용: 특정 trial에 대해 실행)
trial = data.loc[image_idx-1, 'trials']
target_id = data.loc[image_idx-1, 'tid']
target_loc_id = data.loc[image_idx-1, 'tloc']

# Target 정보 설정
target_label = target_labels[target_id]
target_region_index = target_loc_id

# Attention Map 로드 및 정규화
attention_map_path = (f'/content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_{image_idx}.png')
attention_map_image = cv2.imread(attention_map_path, cv2.IMREAD_GRAYSCALE)
attention_map = attention_map_image / 255.0  # Normalize to [0, 1]

# 탐색 실행
fixation_points, found = WTA_with_IOR(
    attention_map,
    search_regions,
    target_region_index,
    max_fixations=6
)

# 결과 출력
if found:
    print(f"Target '{target_label}' found at {fixation_points[-1]} after {len(fixation_points)-1} fixations.")
else:
    print(f"Target '{target_label}' not found after {len(fixation_points)-1} fixations.")

# 탐색 시각화
visualize_search(attention_map, fixation_points)
# Out:
# Target 'sheep' found at (191, 82) after 6 fixations.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

# 데이터 준비
file_path = '/content/drive/MyDrive/Attention/dataset4/data.xlsx'
data = pd.read_excel(file_path)

# Location 정의 (데이터에서의 tloc, sloc 좌표)
locations = {
    0: (33, 157),
    1: (112, 203),
    2: (191, 157),
    3: (191, 67),
    4: (112, 21),
    5: (33, 67)
}

# Target Label 정의
target_labels = {
    0: "cat",
    1: "cattle",
    2: "horse",
    3: "kite",
    4: "sheep",
    5: "teddybear"
}

def define_ROI(fixed_locations, region_size=22):
    """
    Reigion Of Interest 정의 (44x44 matrix 생성).
    """
    return [
        (
            max(0, y - region_size), min(224, y + region_size),
            max(0, x - region_size), min(224, x + region_size)
        )
        for y, x in fixed_locations
    ]

def WTA_with_IOR(attention_map, search_regions, target_region_index, max_fixations=6):
    """
    Attention Map을 기반으로 목표를 탐색.
    """
    attention_map = attention_map.copy()
    fixation_points = [(112, 112)]  # 초기 고정점: Attention Map 중심
    excluded_regions = set()  # 탐색에서 제외된 영역

    for _ in range(max_fixations):
        max_value, max_location, max_region_index = -np.inf, None, None

        for i, region in enumerate(search_regions):
            if i in excluded_regions:
                continue
            y_min, y_max, x_min, x_max = region
            region_values = attention_map[y_min:y_max, x_min:x_max]
            local_max_idx = np.unravel_index(np.argmax(region_values), region_values.shape)
            global_max_idx = (y_min + local_max_idx[0], x_min + local_max_idx[1])

            if attention_map[global_max_idx] > max_value:
                max_value, max_location, max_region_index = attention_map[global_max_idx], global_max_idx, i

        if max_region_index == target_region_index:
            fixation_points.append(max_location)
            return fixation_points, True

        excluded_regions.add(max_region_index)
        fixation_points.append(max_location)

    return fixation_points, False

def is_fixation_in_region(fixation, center, region_radius=22):
    """
    특정 Fixation이 주어진 중심 영역(center) 안에 있는지 확인.
    """
    fy, fx = fixation
    cy, cx = center
    return abs(fy - cy) <= region_radius and abs(fx - cx) <= region_radius

def save_visualization(attention_map, fixation_points, image_idx, output_dir):
    """
    탐색 경로를 표시한 이미지를 저장.
    """
    plt.figure(figsize=(6, 6))
    plt.imshow(attention_map, cmap="viridis")

    for i, (y, x) in enumerate(fixation_points):
        if i == 0:
            plt.plot(x, y, marker='+', markersize=8, color="red")  # 초기 Fixation (중심)
        else:
            plt.scatter(x, y, c="red", s=10)  # 나머지 Fixation
        plt.text(x, y, str(i), color="white", fontsize=8)  # Fixation 번호 표시

    plt.axis("off")  # 축 숨기기
    plt.savefig(f"{output_dir}/search_{image_idx}.png")
    plt.close()

# Output 경로 설정
output_dir = "/content/drive/MyDrive/Attention/dataset4/output_images"
os.makedirs(output_dir, exist_ok=True)

# Fixed Locations 및 ROI 정의
fixed_locations = list(locations.values())
search_regions = define_ROI(fixed_locations, region_size=22)

# 결과 저장 리스트
results = []

# 이미지 1~198 반복 실행
# 이미지 1~300 반복 실행
for image_idx in range(1, 301):
    # image_idx와 trials의 값을 비교하여 해당 행 가져오기
    matching_row = data[data['trials'] == image_idx]

    # image_idx가 존재하지 않을 경우 스킵
    if matching_row.empty:
        print(f"Image index {image_idx} not found in trials. Skipping...")
        continue

    # 해당 행의 데이터 가져오기
    trial = matching_row['trials'].values[0]
    target_id = matching_row['tid'].values[0]
    target_loc_id = matching_row['tloc'].values[0]
    salient_loc_id = matching_row['sloc'].values[0]

    # 타겟 레이블 및 지역 정보
    target_label = target_labels[target_id]
    target_region_index = target_loc_id

    # Attention Map 로드
    attention_map_path = f'/content/drive/MyDrive/Attention/dataset4/heatmap/heatmap_{image_idx}.png'
    attention_map_image = cv2.imread(attention_map_path, cv2.IMREAD_GRAYSCALE)

    # 이미지가 없을 경우 스킵
    if attention_map_image is None:
        print(f"Attention Map for Image {image_idx} not found. Skipping...")
        continue

    # Attention Map 정규화
    attention_map = attention_map_image / 255.0  # Normalize to [0, 1]

    # 탐색 실행
    fixation_points, found = WTA_with_IOR(
        attention_map,
        search_regions,
        target_region_index,
        max_fixations=6
    )


    # sloc 검사
    if salient_loc_id == -1:
        sloc_fixation_index = -1  # salient distractor 없음
    else:
        sloc_center = locations[salient_loc_id]
        sloc_fixation_index = -2  # 초기값: 존재하지만 찍히지 않음
        for idx, fixation in enumerate(fixation_points):
            if is_fixation_in_region(fixation, sloc_center):
                sloc_fixation_index = idx
                break

    # 결과 저장
    results.append({
        "image_idx": image_idx,
        "trial": trial,
        "target_label": target_label,
        "target_location": locations[target_region_index],
        "fixations_count": len(fixation_points) - 1,
        "found": found,
        "sloc_fixation_index": sloc_fixation_index
    })

    # 탐색 경로 이미지 저장
    save_visualization(attention_map, fixation_points, image_idx, output_dir)

    # 진행 상태 출력
    print(f"Processed Image {image_idx}: Target {'found' if found else 'not found'} after {len(fixation_points) - 1} fixations.")

# CSV 파일 저장
results_df = pd.DataFrame(results)
results_csv_path = "/content/drive/MyDrive/Attention/dataset4/search_results.csv"
results_df.to_csv(results_csv_path, index=False)
print(f"Results saved to {results_csv_path}")
# Out:
# Processed Image 1: Target found after 3 fixations.
# Processed Image 2: Target found after 1 fixations.
# Processed Image 3: Target found after 3 fixations.
# Processed Image 4: Target found after 2 fixations.
# Processed Image 5: Target found after 4 fixations.
# Processed Image 6: Target found after 5 fixations.
# Processed Image 7: Target found after 1 fixations.
# Image index 8 not found in trials. Skipping...
# Processed Image 9: Target found after 5 fixations.
# Processed Image 10: Target found after 6 fixations.
# Processed Image 11: Target found after 6 fixations.
# Processed Image 12: Target found after 3 fixations.
# Processed Image 13: Target found after 4 fixations.
# Processed Image 14: Target found after 3 fixations.
# Processed Image 15: Target found after 1 fixations.
# Processed Image 16: Target found after 3 fixations.
# Processed Image 17: Target found after 2 fixations.
# Processed Image 18: Target found after 6 fixations.
# Processed Image 19: Target found after 5 fixations.
# Processed Image 20: Target found after 4 fixations.
# Image index 21 not found in trials. Skipping...
# Processed Image 22: Target found after 3 fixations.
# Processed Image 23: Target found after 1 fixations.
# Image index 24 not found in trials. Skipping...
# Processed Image 25: Target found after 5 fixations.
# Processed Image 26: Target found after 5 fixations.
# Image index 27 not found in trials. Skipping...
# Image index 28 not found in trials. Skipping...
# Processed Image 29: Target found after 1 fixations.
# Image index 30 not found in trials. Skipping...
# Processed Image 31: Target found after 3 fixations.
# Processed Image 32: Target found after 1 fixations.
# Processed Image 33: Target found after 4 fixations.
# Processed Image 34: Target found after 2 fixations.
# Processed Image 35: Target found after 2 fixations.
# Processed Image 36: Target found after 4 fixations.
# Image index 37 not found in trials. Skipping...
# Processed Image 38: Target found after 3 fixations.
# Processed Image 39: Target found after 5 fixations.
# Processed Image 40: Target found after 5 fixations.
# Processed Image 41: Target found after 1 fixations.
# Image index 42 not found in trials. Skipping...
# Processed Image 43: Target found after 6 fixations.
# Processed Image 44: Target found after 4 fixations.
# Image index 45 not found in trials. Skipping...
# Image index 46 not found in trials. Skipping...
# Image index 47 not found in trials. Skipping...
# Image index 48 not found in trials. Skipping...
# Processed Image 49: Target found after 4 fixations.
# Processed Image 50: Target found after 2 fixations.
# Image index 51 not found in trials. Skipping...
# Processed Image 52: Target found after 2 fixations.
# Processed Image 53: Target found after 1 fixations.
# Image index 54 not found in trials. Skipping...
# Processed Image 55: Target found after 4 fixations.
# Processed Image 56: Target found after 1 fixations.
# Processed Image 57: Target found after 5 fixations.
# Processed Image 58: Target found after 3 fixations.
# Processed Image 59: Target found after 1 fixations.
# Processed Image 60: Target found after 5 fixations.
# Processed Image 61: Target found after 2 fixations.
# Processed Image 62: Target found after 2 fixations.
# Processed Image 63: Target found after 2 fixations.
# Processed Image 64: Target found after 1 fixations.
# Processed Image 65: Target found after 4 fixations.
# Processed Image 66: Target found after 4 fixations.
# Processed Image 67: Target found after 2 fixations.
# Processed Image 68: Target found after 1 fixations.
# Processed Image 69: Target found after 4 fixations.
# Processed Image 70: Target found after 3 fixations.
# Processed Image 71: Target found after 2 fixations.
# Processed Image 72: Target found after 2 fixations.
# Processed Image 73: Target found after 4 fixations.
# Processed Image 74: Target found after 2 fixations.
# Processed Image 75: Target found after 6 fixations.
# Processed Image 76: Target found after 4 fixations.
# Processed Image 77: Target found after 1 fixations.
# Processed Image 78: Target found after 3 fixations.
# Processed Image 79: Target found after 2 fixations.
# Image index 80 not found in trials. Skipping...
# Processed Image 81: Target found after 4 fixations.
# Processed Image 82: Target found after 2 fixations.
# Image index 83 not found in trials. Skipping...
# Image index 84 not found in trials. Skipping...
# Processed Image 85: Target found after 5 fixations.
# Processed Image 86: Target found after 1 fixations.
# Processed Image 87: Target found after 2 fixations.
# Image index 88 not found in trials. Skipping...
# Processed Image 89: Target found after 1 fixations.
# Processed Image 90: Target found after 3 fixations.
# Processed Image 91: Target found after 5 fixations.
# Processed Image 92: Target found after 1 fixations.
# Processed Image 93: Target found after 3 fixations.
# Processed Image 94: Target found after 2 fixations.
# Processed Image 95: Target found after 3 fixations.
# Processed Image 96: Target found after 2 fixations.
# Processed Image 97: Target found after 2 fixations.
# Image index 98 not found in trials. Skipping...
# Image index 99 not found in trials. Skipping...
# Image index 100 not found in trials. Skipping...
# Processed Image 101: Target found after 1 fixations.
# Image index 102 not found in trials. Skipping...
# Processed Image 103: Target found after 3 fixations.
# Processed Image 104: Target found after 2 fixations.
# Processed Image 105: Target found after 1 fixations.
# Image index 106 not found in trials. Skipping...
# Image index 107 not found in trials. Skipping...
# Processed Image 108: Target found after 4 fixations.
# Processed Image 109: Target found after 5 fixations.
# Processed Image 110: Target found after 3 fixations.
# Processed Image 111: Target found after 3 fixations.
# Image index 112 not found in trials. Skipping...
# Processed Image 113: Target found after 1 fixations.
# Processed Image 114: Target found after 2 fixations.
# Image index 115 not found in trials. Skipping...
# Processed Image 116: Target found after 4 fixations.
# Processed Image 117: Target found after 4 fixations.
# Processed Image 118: Target found after 6 fixations.
# Processed Image 119: Target found after 5 fixations.
# Processed Image 120: Target found after 1 fixations.
# Processed Image 121: Target found after 3 fixations.
# Processed Image 122: Target found after 2 fixations.
# Processed Image 123: Target found after 1 fixations.
# Processed Image 124: Target found after 6 fixations.
# Processed Image 125: Target found after 1 fixations.
# Processed Image 126: Target found after 2 fixations.
# Processed Image 127: Target found after 1 fixations.
# Processed Image 128: Target found after 4 fixations.
# Processed Image 129: Target found after 3 fixations.
# Processed Image 130: Target found after 1 fixations.
# Image index 131 not found in trials. Skipping...
# Processed Image 132: Target found after 1 fixations.
# Processed Image 133: Target found after 5 fixations.
# Processed Image 134: Target found after 4 fixations.
# Processed Image 135: Target found after 5 fixations.
# Image index 136 not found in trials. Skipping...
# Processed Image 137: Target found after 5 fixations.
# Processed Image 138: Target found after 2 fixations.
# Processed Image 139: Target found after 4 fixations.
# Processed Image 140: Target found after 2 fixations.
# Image index 141 not found in trials. Skipping...
# Image index 142 not found in trials. Skipping...
# Image index 143 not found in trials. Skipping...
# Processed Image 144: Target found after 2 fixations.
# Processed Image 145: Target found after 2 fixations.
# Processed Image 146: Target found after 4 fixations.
# Processed Image 147: Target found after 6 fixations.
# Processed Image 148: Target found after 4 fixations.
# Image index 149 not found in trials. Skipping...
# Processed Image 150: Target found after 1 fixations.
# Processed Image 151: Target found after 2 fixations.
# Processed Image 152: Target found after 4 fixations.
# Processed Image 153: Target found after 6 fixations.
# Processed Image 154: Target found after 6 fixations.
# Processed Image 155: Target found after 1 fixations.
# Processed Image 156: Target found after 1 fixations.
# Processed Image 157: Target found after 6 fixations.
# Processed Image 158: Target found after 6 fixations.
# Processed Image 159: Target found after 2 fixations.
# Processed Image 160: Target found after 3 fixations.
# Processed Image 161: Target found after 1 fixations.
# Processed Image 162: Target found after 1 fixations.
# Processed Image 163: Target found after 4 fixations.
# Image index 164 not found in trials. Skipping...
# Processed Image 165: Target found after 1 fixations.
# Image index 166 not found in trials. Skipping...
# Image index 167 not found in trials. Skipping...
# Processed Image 168: Target found after 5 fixations.
# Processed Image 169: Target found after 6 fixations.
# Processed Image 170: Target found after 2 fixations.
# Image index 171 not found in trials. Skipping...
# Processed Image 172: Target found after 6 fixations.
# Processed Image 173: Target found after 4 fixations.
# Processed Image 174: Target found after 2 fixations.
# Image index 175 not found in trials. Skipping...
# Processed Image 176: Target found after 4 fixations.
# Processed Image 177: Target found after 3 fixations.
# Processed Image 178: Target found after 3 fixations.
# Processed Image 179: Target found after 1 fixations.
# Image index 180 not found in trials. Skipping...
# Processed Image 181: Target found after 5 fixations.
# Processed Image 182: Target found after 6 fixations.
# Processed Image 183: Target found after 1 fixations.
# Processed Image 184: Target found after 6 fixations.
# Processed Image 185: Target found after 1 fixations.
# Processed Image 186: Target found after 4 fixations.
# Processed Image 187: Target found after 6 fixations.
# Processed Image 188: Target found after 2 fixations.
# Processed Image 189: Target found after 1 fixations.
# Processed Image 190: Target found after 5 fixations.
# Image index 191 not found in trials. Skipping...
# Processed Image 192: Target found after 5 fixations.
# Processed Image 193: Target found after 1 fixations.
# Processed Image 194: Target found after 4 fixations.
# Processed Image 195: Target found after 1 fixations.
# Image index 196 not found in trials. Skipping...
# Processed Image 197: Target found after 6 fixations.
# Processed Image 198: Target found after 3 fixations.
# Image index 199 not found in trials. Skipping...
# Image index 200 not found in trials. Skipping...
# Processed Image 201: Target found after 2 fixations.
# Processed Image 202: Target found after 1 fixations.
# Processed Image 203: Target found after 5 fixations.
# Processed Image 204: Target found after 4 fixations.
# Processed Image 205: Target found after 6 fixations.
# Processed Image 206: Target found after 2 fixations.
# Processed Image 207: Target found after 1 fixations.
# Processed Image 208: Target found after 1 fixations.
# Processed Image 209: Target found after 2 fixations.
# Processed Image 210: Target found after 5 fixations.
# Processed Image 211: Target found after 6 fixations.
# Processed Image 212: Target found after 2 fixations.
# Processed Image 213: Target found after 5 fixations.
# Processed Image 214: Target found after 2 fixations.
# Processed Image 215: Target found after 5 fixations.
# Processed Image 216: Target found after 4 fixations.
# Processed Image 217: Target found after 6 fixations.
# Processed Image 218: Target found after 1 fixations.
# Processed Image 219: Target found after 1 fixations.
# Processed Image 220: Target found after 1 fixations.
# Processed Image 221: Target found after 4 fixations.
# Processed Image 222: Target found after 2 fixations.
# Processed Image 223: Target found after 4 fixations.
# Processed Image 224: Target found after 2 fixations.
# Processed Image 225: Target found after 2 fixations.
# Processed Image 226: Target found after 3 fixations.
# Processed Image 227: Target found after 2 fixations.
# Processed Image 228: Target found after 6 fixations.
# Processed Image 229: Target found after 2 fixations.
# Processed Image 230: Target found after 2 fixations.
# Processed Image 231: Target found after 2 fixations.
# Processed Image 232: Target found after 1 fixations.
# Processed Image 233: Target found after 5 fixations.
# Processed Image 234: Target found after 1 fixations.
# Processed Image 235: Target found after 5 fixations.
# Processed Image 236: Target found after 5 fixations.
# Processed Image 237: Target found after 5 fixations.
# Processed Image 238: Target found after 1 fixations.
# Processed Image 239: Target found after 3 fixations.
# Processed Image 240: Target found after 4 fixations.
# Processed Image 241: Target found after 2 fixations.
# Processed Image 242: Target found after 1 fixations.
# Processed Image 243: Target found after 1 fixations.
# Processed Image 244: Target found after 1 fixations.
# Processed Image 245: Target found after 5 fixations.
# Processed Image 246: Target found after 4 fixations.
# Processed Image 247: Target found after 5 fixations.
# Processed Image 248: Target found after 4 fixations.
# Processed Image 249: Target found after 5 fixations.
# Processed Image 250: Target found after 3 fixations.
# Processed Image 251: Target found after 4 fixations.
# Processed Image 252: Target found after 3 fixations.
# Processed Image 253: Target found after 6 fixations.
# Processed Image 254: Target found after 1 fixations.
# Processed Image 255: Target found after 3 fixations.
# Processed Image 256: Target found after 3 fixations.
# Processed Image 257: Target found after 6 fixations.
# Processed Image 258: Target found after 6 fixations.
# Processed Image 259: Target found after 4 fixations.
# Processed Image 260: Target found after 4 fixations.
# Processed Image 261: Target found after 5 fixations.
# Processed Image 262: Target found after 2 fixations.
# Processed Image 263: Target found after 6 fixations.
# Processed Image 264: Target found after 4 fixations.
# Processed Image 265: Target found after 3 fixations.
# Processed Image 266: Target found after 4 fixations.
# Processed Image 267: Target found after 4 fixations.
# Processed Image 268: Target found after 2 fixations.
# Processed Image 269: Target found after 3 fixations.
# Processed Image 270: Target found after 4 fixations.
# Processed Image 271: Target found after 6 fixations.
# Processed Image 272: Target found after 1 fixations.
# Processed Image 273: Target found after 2 fixations.
# Processed Image 274: Target found after 3 fixations.
# Processed Image 275: Target found after 1 fixations.
# Processed Image 276: Target found after 1 fixations.
# Processed Image 277: Target found after 4 fixations.
# Processed Image 278: Target found after 3 fixations.
# Processed Image 279: Target found after 1 fixations.
# Image index 280 not found in trials. Skipping...
# Image index 281 not found in trials. Skipping...
# Image index 282 not found in trials. Skipping...
# Image index 283 not found in trials. Skipping...
# Image index 284 not found in trials. Skipping...
# Image index 285 not found in trials. Skipping...
# Image index 286 not found in trials. Skipping...
# Image index 287 not found in trials. Skipping...
# Image index 288 not found in trials. Skipping...
# Image index 289 not found in trials. Skipping...
# Image index 290 not found in trials. Skipping...
# Image index 291 not found in trials. Skipping...
# Image index 292 not found in trials. Skipping...
# Image index 293 not found in trials. Skipping...
# Image index 294 not found in trials. Skipping...
# Image index 295 not found in trials. Skipping...
# Image index 296 not found in trials. Skipping...
# Image index 297 not found in trials. Skipping...
# Image index 298 not found in trials. Skipping...
# Image index 299 not found in trials. Skipping...
# Image index 300 not found in trials. Skipping...
# Results saved to /content/drive/MyDrive/Attention/dataset4/search_results.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import f_oneway, ttest_ind

# 데이터 로드
file_path = "/content/drive/MyDrive/Attention/dataset4/search_results.csv"
data = pd.read_csv(file_path)

# 조건 정의
color_mismatch_idx = list(range(1, 101))
color_match_idx = list(range(101, 201))
nonmatch_idx = list(range(201, 301))

# 조건별 데이터 필터링
color_mismatch = data[data['image_idx'].isin(color_mismatch_idx)]
color_match = data[data['image_idx'].isin(color_match_idx)]
nonmatch = data[data['image_idx'].isin(nonmatch_idx)]

# fixations_count의 평균과 표준편차 계산
conditions_summary = {
    "Condition": ["Color Mismatch", "Color Match", "Nonmatch"],
    "Mean Fixations Count": [
        color_mismatch['fixations_count'].mean(),
        color_match['fixations_count'].mean(),
        nonmatch['fixations_count'].mean()
    ],
    "Std Fixations Count": [
        color_mismatch['fixations_count'].std(),
        color_match['fixations_count'].std(),
        nonmatch['fixations_count'].std()
    ]
}

# 데이터프레임 생성
summary_df = pd.DataFrame(conditions_summary)

# fixations_count 차이 유의성 검정 (ANOVA)
anova_result = f_oneway(
    color_mismatch['fixations_count'],
    color_match['fixations_count'],
    nonmatch['fixations_count']
)

# sloc_fixation_index 누적값 계산
sloc_trials = data[(data['image_idx'] >= 1) & (data['image_idx'] <= 200)]
sloc_counts = sloc_trials['sloc_fixation_index'].value_counts().reindex(range(1, 7), fill_value=0)

# sloc_fixation_index가 1인 비율 계산
sloc_index_1_ratio = len(sloc_trials[sloc_trials['sloc_fixation_index'] == 1]) / len(sloc_trials)

# sloc_fixation_index가 1인 비율 (조건별)
color_mismatch_sloc_1_ratio = len(color_mismatch[color_mismatch['sloc_fixation_index'] == 1]) / len(color_mismatch)
color_match_sloc_1_ratio = len(color_match[color_match['sloc_fixation_index'] == 1]) / len(color_match)

# Pairwise T-tests for post-hoc analysis
ttest_results = {
    "Color Mismatch vs. Color Match": ttest_ind(
        color_mismatch['fixations_count'], color_match['fixations_count'], equal_var=False
    ),
    "Color Mismatch vs. Nonmatch": ttest_ind(
        color_mismatch['fixations_count'], nonmatch['fixations_count'], equal_var=False
    ),
    "Color Match vs. Nonmatch": ttest_ind(
        color_match['fixations_count'], nonmatch['fixations_count'], equal_var=False
    )
}

# Results output
pairwise_results = []
for comparison, result in ttest_results.items():
    pairwise_results.append({
        "Comparison": comparison,
        "T-statistic": result.statistic,
        "P-value": result.pvalue
    })

# Pairwise T-Test 결과 데이터프레임 생성
pairwise_df = pd.DataFrame(pairwise_results)

# 통계량을 하나의 데이터프레임으로 정리
stats_summary = {
    "Statistic": ["ANOVA F-statistic", "ANOVA P-value"] +
                 [f"{row['Comparison']} T-statistic" for _, row in pairwise_df.iterrows()] +
                 [f"{row['Comparison']} P-value" for _, row in pairwise_df.iterrows()],
    "Value": [anova_result.statistic, anova_result.pvalue] +
             list(pairwise_df["T-statistic"]) +
             list(pairwise_df["P-value"])
}
stats_summary_df = pd.DataFrame(stats_summary)

# 시각화: 두 그래프를 하나의 열에 배치
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# 첫 번째 그래프: Fixations Count (Mean ± Std)
x_labels = ["Color Mismatch", "Color Match", "Nonmatch"]
means = summary_df["Mean Fixations Count"]
stds = summary_df["Std Fixations Count"]
axs[0].bar(x_labels, means, yerr=stds, capsize=5, alpha=0.7, color=['blue', 'green', 'orange'])
axs[0].set_ylabel("Fixations Count (Mean ± Std)")
axs[0].set_title("Fixations Count by Condition")

# 두 번째 그래프: sloc_fixation_index 누적값
sloc_counts.plot(kind='bar', color='purple', alpha=0.7, ax=axs[1])
axs[1].set_xlabel("sloc_fixation_index")
axs[1].set_ylabel("Cumulative Count")
axs[1].set_title("Cumulative sloc_fixation_index (1-200 Trials)")
axs[1].tick_params(axis='x', rotation=0)

plt.tight_layout()
plt.show()

# 결과 테이블 출력
print("\nConditions Summary:")
print(summary_df)

# ANOVA 결과 출력
print("\nANOVA result (fixations_count differences between conditions):")
print(f"F-statistic: {anova_result.statistic:.4f}, p-value: {anova_result.pvalue:.4f}")

# sloc_fixation_index = 1 비율 출력
print(f"\nsloc_fixation_index = 1 Ratio (1-200 Trials): {sloc_index_1_ratio:.4f}")
print(f"sloc_fixation_index = 1 Ratio (Color Mismatch): {color_mismatch_sloc_1_ratio:.4f}")
print(f"sloc_fixation_index = 1 Ratio (Color Match): {color_match_sloc_1_ratio:.4f}")

# Pairwise T-Test 결과 출력
print("\nPairwise T-Test Results:")
print(pairwise_df)

# 유의미한 Pairwise Comparisons
significant_comparisons = pairwise_df[pairwise_df['P-value'] < 0.05]
print("\nSignificant Pairwise Comparisons (P < 0.05):")
print(significant_comparisons)
# Out:
# Conditions Summary:
#         Condition  Mean Fixations Count  Std Fixations Count
# 0  Color Mismatch              3.000000             1.544220
# 1     Color Match              3.202532             1.828407
# 2        Nonmatch              3.202532             1.697508
#
# ANOVA result (fixations_count differences between conditions):
# F-statistic: 0.3764, p-value: 0.6867
#
# sloc_fixation_index = 1 Ratio (1-200 Trials): 0.2152
# sloc_fixation_index = 1 Ratio (Color Mismatch): 0.1646
# sloc_fixation_index = 1 Ratio (Color Match): 0.2658
#
# Pairwise T-Test Results:
#                        Comparison  T-statistic   P-value
# 0  Color Mismatch vs. Color Match    -0.752171  0.453113
# 1     Color Mismatch vs. Nonmatch    -0.784440  0.433982
# 2        Color Match vs. Nonmatch     0.000000  1.000000
#
# Significant Pairwise Comparisons (P < 0.05):
# Empty DataFrame
# Columns: [Comparison, T-statistic, P-value]
# Index: []
